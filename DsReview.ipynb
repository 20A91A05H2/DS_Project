# %% [markdown]
# <a href="https://colab.research.google.com/github/20A91A05H2/DS_Project/blob/main/DsReview.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#IMPORTS
import pandas as pd
from sklearn.linear_model import LinearRegression
from matplotlib import pyplot as plt

# %%
#DATA HANDLING
import pandas as pd
from sklearn.linear_model import LinearRegression
from matplotlib import pyplot as plt
data = pd.read_csv('/content/Private_data.csv')
print(data.head())
print(data.describe())
# Out:
#   NAME OF THE STUDENT                UNIVERSITY PROGRAM NAME  \
# 0         Camila Wood  Stanford University, USA        B.Com
# 1  Alexander Thompson  Stanford University, USA        B.Com
# 2         Liam Taylor   Harvard University, USA        B.Com
# 3      Evelyn Jenkins  Stanford University, USA        B.Com
# 4     Michael Jackson   Harvard University, USA          MBA
#
#            Specialisation SEMESTER   Domain  \
# 0                 Honours      5th  Finance
# 1      Financial Services      5th  Finance
# 2    Accounting Analytics      5th       BA
# 3                 Honours      5th  Finance
# 4  International Business      3rd       IB
#
#    GENERAL MANAGEMENT SCORE (OUT of 50)  Domain Specific SCORE (OUT 50)  \
# 0                                    50                              50
# 1                                    50                              50
# 2                                    50                              50
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
X = data[["TOTAL SCORE (OUT of 100)"]]
Y = data["PERCENTILE"]
Y_ = data["RANK"]

# %%
#DATA ANALYSIS
plt.scatter(X['TOTAL SCORE (OUT of 100)'], Y, color='b')
plt.xlabel('PERCENTILE')
plt.ylabel('RANK')
plt.show()

# %%
#LINEAR REGRESSION
mdl = LinearRegression()
mdl.fit(X, Y)
pred = mdl.predict([[6.575]])
print("Predicted value (LR): ",pred[0])
print("Accuracy (LR): ",mdl.score(X[:100], Y[:100])*100)

plt.scatter(X['TOTAL SCORE (OUT of 100)'], Y, color='b')
plt.plot(X['TOTAL SCORE (OUT of 100)'], mdl.predict(X),color='black',linewidth=3)
plt.xlabel('TOTAL SCORE (OUT of 100)')
plt.ylabel('RANK')
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# Predicted value (LR):  -0.346157043115206
# Accuracy (LR):  87.52500170986906

# %%
#LOGISTIC REGRESSION
from sklearn.linear_model import LogisticRegression
mdl = LogisticRegression()
mdl.fit(X, Y_)
pred = mdl.predict([[6.575]])
print("Predicted value (LGR): ",pred[0])
print("Accuracy (LGR): ",mdl.score(X[:100], Y_[:100])*100)

plt.scatter(X['TOTAL SCORE (OUT of 100)'], Y_, color='b')
plt.plot(X['TOTAL SCORE (OUT of 100)'], mdl.predict(X),color='black',linewidth=3)
plt.xlabel('TOTAL SCORE (OUT of 100)')
plt.ylabel('RANK')
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# Predicted value (LGR):  151
# Accuracy (LGR):  17.0

# %%
#SVR
from sklearn.svm import SVR
mdl = SVR(kernel = 'rbf')
mdl.fit(X, Y)
pred = mdl.predict([[6.575]])
print("Predicted value (SVR): ",pred[0])
print("Accuracy (SVR): ",mdl.score(X[:100], Y[:100])*100)

plt.scatter(X['TOTAL SCORE (OUT of 100)'], Y, color='b')
plt.plot(X['TOTAL SCORE (OUT of 100)'], mdl.predict(X),color='black',linewidth=3)
plt.xlabel('TOTAL SCORE (OUT of 100)')
plt.ylabel('RANK')
plt.show()
# Out:
# Predicted value (SVR):  0.09851052557215928
# Accuracy (SVR):  96.12324896007216
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but SVR was fitted with feature names
#   warnings.warn(

# %%
#SVC
from sklearn.svm import SVC
mdl = SVC(kernel='poly')
mdl.fit(X, Y_)
pred = mdl.predict([[6.575]])
print("Predicted value (SVC): ",pred[0])
#print("Accuracy (SVR): ",mdl.score(X[:100], Y[:100])*100)
plt.scatter(X['TOTAL SCORE (OUT of 100)'], Y_, color='b')
plt.plot(X['TOTAL SCORE (OUT of 100)'], mdl.predict(X),color='black',linewidth=3)
plt.xlabel('TOTAL SCORE (OUT of 100)')
plt.ylabel('RANK')
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# Predicted value (SVC):  151

# %%
#NB
from sklearn.naive_bayes import GaussianNB
mdl = GaussianNB()
mdl.fit(X, Y_)
pred = mdl.predict([[6.575]])
print("Predicted value (NB): ",pred[0])
print("Accuracy (NB): ",mdl.score(X[:100], Y_[:100])*100)

plt.scatter(X['TOTAL SCORE (OUT of 100)'], Y_, color='b')
plt.plot(X['TOTAL SCORE (OUT of 100)'], mdl.predict(X),color='black',linewidth=3)
plt.xlabel('TOTAL SCORE (OUT of 100)')
plt.ylabel('RANK')
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but GaussianNB was fitted with feature names
#   warnings.warn(
# Predicted value (NB):  151
# Accuracy (NB):  31.0

# %%
#KNN
from sklearn.neighbors import KNeighborsClassifier
mdl = KNeighborsClassifier()
mdl.fit(X, Y_)
pred = mdl.predict([[6.575]])
print("Predicted value (KNN): ",pred[0])
print("Accuracy (KNN): ",mdl.score(X[:100], Y_[:100])*100)

plt.scatter(X['TOTAL SCORE (OUT of 100)'], Y_, color='b')
plt.plot(X['TOTAL SCORE (OUT of 100)'], mdl.predict(X),color='black',linewidth=3)
plt.xlabel('TOTAL SCORE (OUT of 100)')
plt.ylabel('RANK')
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(
# Predicted value (KNN):  147
# Accuracy (KNN):  21.0

# %%
#RANDOM FOREST CLASSIFICATION
from sklearn.ensemble import RandomForestClassifier
mdl = RandomForestClassifier(criterion='entropy')
mdl.fit(X, Y_)
pred = mdl.predict([[6.575]])
print("Predicted value (RFC): ",pred[0])
print("Accuracy (RFC): ",mdl.score(X[:100], Y_[:100])*100)

plt.scatter(X['TOTAL SCORE (OUT of 100)'], Y_, color='b')
plt.plot(X['TOTAL SCORE (OUT of 100)'], mdl.predict(X),color='black',linewidth=3)
plt.xlabel('TOTAL SCORE (OUT of 100)')
plt.ylabel('RANK')
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# Predicted value (RFC):  151
# Accuracy (RFC):  31.0

# %%
#RANDOM FOREST REGRESSION
from sklearn.ensemble import RandomForestRegressor
mdl = RandomForestRegressor(n_estimators=100,max_depth=6)
mdl.fit(X, Y)
pred = mdl.predict([[6.575]])
print("Predicted value (RFR): ",pred[0])
print("Accuracy (RFR): ",mdl.score(X[:100], Y[:100])*100)

plt.scatter(X['TOTAL SCORE (OUT of 100)'], Y, color='b')
plt.plot(X['TOTAL SCORE (OUT of 100)'], mdl.predict(X),color='black',linewidth=3)
plt.xlabel('TOTAL SCORE (OUT of 100)')
plt.ylabel('RANK')
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# Predicted value (RFR):  0.011550772855666684
# Accuracy (RFR):  99.78241402601125

# %%
#DECISION TREE CLASSIFICATION
from sklearn.tree import DecisionTreeClassifier
mdl = DecisionTreeClassifier(max_leaf_nodes=3, random_state=1)
mdl.fit(X, Y_)
pred = mdl.predict([[6.575]])
print("Predicted value (DTC): ",pred[0])
print("Accuracy (DTC): ",mdl.score(X[:100], Y_[:100])*100)

plt.scatter(X['TOTAL SCORE (OUT of 100)'], Y_, color='b')
plt.plot(X['TOTAL SCORE (OUT of 100)'], mdl.predict(X),color='black',linewidth=3)
plt.xlabel('TOTAL SCORE (OUT of 100)')
plt.ylabel('RANK')
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# Predicted value (DTC):  151
# Accuracy (DTC):  1.0

# %%
#DECISION TREE REGRESSION
from sklearn.tree import DecisionTreeRegressor
mdl =  DecisionTreeRegressor(max_depth=3)
mdl.fit(X, Y)
pred = mdl.predict([[6.575]])
print("Predicted value (DTR): ",pred[0])
print("Accuracy (DTR): ",mdl.score(X[:100], Y[:100])*100)

plt.scatter(X['TOTAL SCORE (OUT of 100)'], Y, color='b')
plt.plot(X['TOTAL SCORE (OUT of 100)'], mdl.predict(X),color='black',linewidth=3)
plt.xlabel('TOTAL SCORE (OUT of 100)')
plt.ylabel('RANK')
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# Predicted value (DTR):  0.06291390727777778
# Accuracy (DTR):  96.23042304298734

# %%
#MULTIPLE LINEAR REGRESSION
X = data[["TOTAL SCORE (OUT of 100)","RANK"]]
mdl = LinearRegression()
mdl.fit(X, Y)
pred = mdl.predict([[6.575, 4.09]])
print("Predicted value (MLR): ",pred[0])
print("Accuracy (MLR): ",mdl.score(X[:100], Y[:100])*100)

plt.scatter(X['TOTAL SCORE (OUT of 100)'], Y, color='b')
plt.plot(X['TOTAL SCORE (OUT of 100)'], mdl.predict(X),color='black',linewidth=3)
plt.xlabel('TOTAL SCORE (OUT of 100)')
plt.ylabel('RANK')
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# Predicted value (MLR):  0.9795364241627045
# Accuracy (MLR):  100.0

# %%
score=91.24
MAE=1.678976757
print("Accuracy of Linear Regression",score)
print("MAE",MAE)
# Out:
# Accuracy of Linear Regression 91.24
# MAE 1.678976757

# %%
#TESTING
#RandomForestRegressor
x=data[['TOTAL SCORE (OUT of 100)','GENERAL MANAGEMENT SCORE (OUT of 50)']]
y=data[['RANK','Domain Specific SCORE (OUT 50)']]

from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=1)



from sklearn.ensemble import RandomForestRegressor
import numpy as np
from sklearn.metrics import r2_score
rf_model=RandomForestRegressor(n_estimators=100, random_state=42)

rf_model.fit(x_train, y_train)
y_pred=rf_model.predict(x_test)
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
mse=mean_squared_error(y_test,y_pred)
acc=mse
r2=r2_score(y_test,y_pred)
mae=mean_absolute_error(y_test,y_pred)

# Calculate the accuracy of the model
acc = mse# Calculate the accuracy of the model
print("Mean Square Error of RandomForest Regression",mse)
print("R2 score of RandomForest Regression",r2)
print("Mean absolute Error of RandomForest Regression",mae)


# Calculate the accuracy of the model
# Calculate the accuracy of the model

# Print the accuracy
print(f"Accuracy: {acc:.2f}")
# Out:
# Mean Square Error of RandomForest Regression 4.37623058894766
# R2 score of RandomForest Regression 0.9770010307465351
# Mean absolute Error of RandomForest Regression 1.6382322708653358
# Accuracy: 4.38
